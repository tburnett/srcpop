# %%
# %run pylib/setup summary
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f198addfb50>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f198addfc70>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f198addf730>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f198adde680>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f198adddea0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f198addfb80>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f198adde1a0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f198addfd60>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f198addf4f0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f198addeb30>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f198a97af50>
# ...
