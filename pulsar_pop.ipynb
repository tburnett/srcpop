# %%
# %run pylib/pulsar_pop main
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f616d7284c0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f616d72b400>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f616d72b3d0>
# Loaded UW model uw1410: 11786 entries
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f616b8055d0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f616b805270>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f616b347ee0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f616b3993f0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f616b949ba0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f616b4b7af0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f616cbb57b0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f616cd63730>
# ...
