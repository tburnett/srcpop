# %%
# %run pylib/unid_analysis dark dr4 unid-doc
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f85c5fd9840>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f85c0dc9c90>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f85c2393340>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f85c23931f0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f85c2392170>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f85c2390be0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f85c11333a0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f85c0f8af50>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f85c0344b20>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f85c03467a0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f85c04a26e0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f85c04db5b0>
# ...

# %%
with capture_hide():
    self.check_hpm()
show('### AIT plot')
show_fig(self.ait)

show("""### Anti-center """)
show_fig(self.zea, 180,0, caption=self.zea.__doc__)
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fec49ff6560>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fec60cda530>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fec60cda7d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fec64983310>
