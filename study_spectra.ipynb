# %%
# %run pylib/spectral_shapes doc
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f228840fd30>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f2262ab8280>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f2262ab92a0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f2262ab9de0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f2225adcdc0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f2225adcd00>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /mnt/c/Users/thbur/onedrive/work/srcpop/pylib/spectral_shapes.py:112
#     110 arg = sys.argv[1]
#     111 if arg=='doc':
# --> 112     main()
#     113 elif arg=='setup':
#     114     setup()
#
# File /mnt/c/Users/thbur/onedrive/work/srcpop/pylib/spectral_shapes.py:104, in main()
#     102 fs_data, train_df, unid_df = setup()
# ...
