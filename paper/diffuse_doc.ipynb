# %%
# %run pylib/unid_analysis diffuse-doc dark
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cd618b20>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cd61bfa0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cd61a320>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cd61aef0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cd61a590>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cd478be0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cd2c1480>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cd61a620>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cd1ad7b0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cb0063e0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cb004d90>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cd13f130>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1cd1633d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1c78c83a0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1c7892c80>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1c5852cb0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1c5aef880>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1c592c910>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1c5853a90>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1c5b23eb0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1c59e0a60>

# %%
show_fig(self.zea, 180,0, caption=self.zea.__doc__)
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7ff1c5f768f0>

# %%
show_fig(self.zea, 300,0, caption=self.zea.__doc__)

# %%
def zea( *args, size=90, hue_order=None, df=None):
    """ZEA projection of the galactic diffuse with positions of pulsars and the unid-pulsar category"""
    self.check_hpm()
    ax = self.zea_plot(*args, size=size)
    self._plot_psr( ax,  hue_order=['unid-pulsar'])
    
    for name in ['HH 211', 'HH 212']:#,palette=['maroon']) 
        d=SkyCoord.from_name(name).galactic;     
        ax.scatter(d, s=300, marker='+', color='red' )
        ax.text(d, name, color='red',fontsize=12)
    ax.grid(color='0.5', ls='-')
    return ax.figure

fig = zea( 180, -10, size=60, df=self.df)
# ax = fig.axes[0]
# for name in ['HH 211', 'HH 212']:#,palette=['maroon']) 
#     d=SkyCoord.from_name(name).galactic;     
#     ax.scatter(d, s=300, marker='+', color='red' )
#     ax.text(d, name, color='red',fontsize=12)

# %%
fig.axes[0]

# %%
from pylib.skymaps import  _process_args
center, _ = _process_args(l,b); center

# %%
from astropy.coordinates import SkyCoord
d = SkyCoord.from_name('HH 212').galactic; d

# %%
d.l.deg, d.b.deg

# %%
d = SkyCoord.from_name('HH 211').galactic; d
