# %%
# %run pylib/compare_epeak
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f8a26968490>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f8a2696ae00>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f8a2696ae90>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f8a2696bf40>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f8a2487ffa0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f8a2487d0c0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f8a2485e170>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f8a24bac3a0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7f8a24885cc0>
