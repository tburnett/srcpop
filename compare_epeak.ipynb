# %%
# %run pylib/compare_epeak
# Out:
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd5fc670400>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd5fc673910>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd6377e4490>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd5fa6e34c0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd5fa905ae0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd5fa89f6d0>
# <utilities.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd5fa6e0730>
