# %%
# %run pylib/summary doc dark
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fdecc7e7940>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fdecc6324d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fdecc631a50>
# * Load diffuse file,  `/mnt/c/users/thbur/OneDrive/fermi/diffuse/gll_iem_v07_hpx.fits`<br>  unit=$\rm{eV\ cm^{-2}\ s^{-1}\ deg^{-2}}$<br>  select energy= 893 MeV
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fde804b80a0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fde802e15d0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fde80058580>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fde80239270>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fde7e75b460>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fde80059660>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fde7e75b4c0>
# ...
