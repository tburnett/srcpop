# %%
# %run pylib/fermi_sources
show("""# Revisit the spectra of the 99
""")
data = pd.read_csv('files/hcu_candidates.csv', index_col=0)
# show(data.head())

show(f"""## The plot from the [paper pre-draft](pulsar_pop.ipynb)---
But forcing the 4FGL fit to be PLEC4.
""")
sedplotgrid(data, plec=True)
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd964224cd0>
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd9033832e0>
# /mnt/c/Users/thbur/onedrive/work/srcpop/pylib/spectral_functions.py:218: RuntimeWarning: overflow encountered in power
#   return n0*x**(-gamma+d/b)*np.exp((d/b**2)*(1-x**b))
# /mnt/c/Users/thbur/onedrive/work/srcpop/pylib/spectral_functions.py:218: RuntimeWarning: invalid value encountered in multiply
#   return n0*x**(-gamma+d/b)*np.exp((d/b**2)*(1-x**b))
# /mnt/c/Users/thbur/onedrive/work/srcpop/pylib/spectral_functions.py:218: RuntimeWarning: overflow encountered in exp
#   return n0*x**(-gamma+d/b)*np.exp((d/b**2)*(1-x**b))
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd902375a80>

# %%
show(f"""## Compare the PLEC and LP spectral shapes 
Use the catalog spectral function information to look at the special 99.
""")
from .catalogs import Fermi4FGL
fgl = Fermi4FGL()
def test(i,ax):

    src_name = data.iloc[i].name
    # ax.set_title(src_name)
    for func in 'PLEC4 LP'.split():
        fgl.get_specfunc( src_name, func).sed_plot(ax=ax, ylim=(0.1, 10), )
fig, axx = plt.subplots(ncols=10, nrows=10, figsize=(15,15),sharex=True, sharey=True)
for i,ax in zip(range(99),axx.flat):
    test(i,ax)
    ax.set(ylabel='', xlabel='',  xticks=[], yticks=[])
show(fig)
# Out:
# <pylib.ipynb_docgen.doc_formatter.<locals>.MimeBundleObject at 0x7fd9020e54e0>
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       1 show(f"""## Compare the PLEC and LP spectral shapes
#       2 Use the catalog spectral function information to look at the special 99.
#       3 """)
# ----> 4 from .catalogs import Fermi4FGL
#       5 fgl = Fermi4FGL()
#       6 def test(i,ax):
#
# ImportError: attempted relative import with no known parent package
